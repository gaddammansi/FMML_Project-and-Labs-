# %% [markdown]
# <a href="https://colab.research.google.com/github/gaddammansi/FMML_Project-and-Labs-/blob/main/module_8_lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-26 17:46:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  85.1MB/s    in 0.8s
#
# 2024-04-26 17:46:09 (85.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2279   1801.00085v1  Learning probability distributions on the weig...  stat
# 12641  cs/0212040v1  We have analyzed manufacturing data from sever...    cs
# 8109    1406.4296v2  Learning object detectors requires massive amo...    cs
# 29870  1710.10565v1  Reliability and accuracy of iris biometric mod...    cs
# 7208   1711.01204v2  Neural samplers such as variational autoencode...  stat
# ...             ...                                                ...   ...
# 31915   1208.6231v1  This study deals with the missing link predict...    cs
# 30954  1801.10109v1  Recently, great progress has been made for onl...    cs
# 31830   1011.1576v4  An importance weight quantifies the relative i...    cs
# 10768   1402.2676v4  We propose RoBiRank, a ranking algorithm that ...  stat
# 32197   1212.3185v3  In data mining applications, feature selection...    cs
#
#                                                    title  year  \
# 2279   Learning Structural Weight Uncertainty for Seq...  2017
# 12641  Data Engineering for the Analysis of Semicondu...  2002
# 8109   Self-Learning Camera: Autonomous Adaptation of...  2014
# 29870    Synthetic Iris Presentation Attack using iDCGAN  2017
# 7208                  Metrics for Deep Generative Models  2017
# ...                                                  ...   ...
# 31915  Link Prediction via Generalized Coupled Tensor...  2012
# 30954  Trajectory-based Radical Analysis Network for ...  2018
# 31830             Online Importance Weight Aware Updates  2010
# 10768  Ranking via Robust Binary Classification and P...  2014
# 32197  Cost-Sensitive Feature Selection of Data with ...  2012
#
#                                                 keywords
# 2279   [probability, distributions, beneficial, appli...
# 12641  [manufacturing, different, semiconductor, manu...
# 8109   [detectors, impractical, different, constantly...
# 29870  [reliability, biometric, deployment, applicati...
# 7208   [variational, autoencoders, generative, advers...
# ...                                                  ...
# 31915  [prediction, predicting, existence, connection...
# 30954  [handwritten, character, recognition, emergenc...
# 31830  [importance, quantifies, importance, applicati...
# 10768  [algorithm, motivated, observing, connection, ...
# 32197  [applications, selection, essential, complexit...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2279     [probability, distributions, beneficial, appli...
# 12641    [manufacturing, different, semiconductor, manu...
# 8109     [detectors, impractical, different, constantly...
# 29870    [reliability, biometric, deployment, applicati...
# 7208     [variational, autoencoders, generative, advers...
#                                ...
# 10260    [increasing, sensitive, information, aggregate...
# 13329    [information, revolution, increased, globaliza...
# 6650     [motivated, applications, autonomous, techniqu...
# 3350     [generative, developed, representation, hierar...
# 11198    [improving, efficiency, randomized, accelerate...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8766 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d17459a-4cdf-4176-8828-295694af1b88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d17459a-4cdf-4176-8828-295694af1b88")) {                    Plotly.newPlot(                        "5d17459a-4cdf-4176-8828-295694af1b88",                        [{"x":["beneficial","reinforcement","variational","investigate","employing","knowledge","applications","synthetic","distributions","posterior","uncertainty","including","framework","efficient","probability","information","parameters","sequential","structural","superiority","contextual","experiments","individual","independent","preprocessing","manufacturing","importance","granularity","important","generates","predicting","different","induction","discusses","encountered","definition","experience","semiconductor","representation","rejection","engineers","facilitate","understanding","engineering","unsupervised","assistant","adaptation","autonomous","transductive","unlabeled","impractical","detectors","intervention","efficiently","available","validated","continuously","objective","constantly","precision","structure","streaming","algorithm","confident","themselves","paramount","generated","generating","capability","realistic","appearing","adversarial","recognition","generation","detection","deployment","commercial","illustrate","researchers","extensive","utilizing","mitigating","generative","demonstrate","presentation","discriminate","biometric","susceptibility","synthetically","convolutional","experimental","reliability","evaluated","interpolation","handwritten","alternative","principled","hypothesis","approximate","separated","criterions","transforming","autoencoders","riemannian","stationary","distribution","observation","simulated","represented","generalization","similarity","consequently","distances","inspection","previously","transformation","simultaneously","informative","architecture","preserving","illustrated","recommendation","distributed","associated","described","regularization","algorithmic","methodologies","algorithms","developments","decisions","processes","artificial","dependent","implications","increasingly","responsible","intelligent","deliberation","direction","stakeholders","designers","technological","integrate","considerable","unification","complexity","inference","particular","biomedical","description","polynomial","precisely","ontologies","decidable","attention","redundancies","significant","solutions","constrain","stochastic","separable","introduces","supervision","representations","collapsing","remarkably","questions","defeasible","structured","formalization","approaches","monotonic","reasoning","conclusion","construction","disjunctive","intricate","argumentation","subtleties","regarding","arguments","systematically","computation","artifacts","experimentation","influence","relatively","architectures","performance","compression","comprehensive","currently","verification","strengths","brightness","characteristics","squeezenet","occlusion","descriptor"],"y":[18,106,51,131,32,368,447,145,117,27,78,237,550,430,162,683,245,73,63,36,58,599,114,121,20,14,59,11,317,47,87,773,22,32,8,41,32,1,378,7,9,46,168,58,146,5,65,52,7,36,12,38,13,177,321,31,22,179,2,79,360,12,798,3,23,4,184,90,73,58,13,104,403,138,334,27,14,73,78,154,37,5,121,583,15,13,10,3,11,374,399,21,156,15,23,103,36,55,109,11,0,13,17,8,20,210,61,65,69,103,127,31,37,5,115,52,117,33,245,45,21,35,94,110,69,96,41,17,591,30,58,101,134,64,17,48,7,50,2,61,3,10,10,47,36,6,230,193,246,19,71,65,24,25,7,157,4,231,151,10,129,7,80,51,222,1,12,71,3,97,12,444,15,125,18,69,11,8,9,3,34,16,15,164,26,18,70,72,122,906,46,60,51,40,18,2,81,2,20,35],"type":"bar"},{"x":["beneficial","reinforcement","variational","investigate","e ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Internet</span> <span style=''>of</span> <span style=''>Things</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>Animal</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Monitoring</span> <span style=''>with</span> <span style=''>Unmanned</span> <span style=''>Aerial</span> <span style=''>Vehicle</span> <br/><br/><span style=''>In</span> <span style=''>animal</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>monitoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>both</span> <span style=''>animal</span> <span style='background-color:rgba(0, 255, 0, 0.5754716981132075);'>detection</span> <span style=''>and</span> <span style=''>their</span> <span style=''>movement</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>are</span> <span style=''>major</span> <span style=''>tasks</span> <span style=''>While</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>animal</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>monitoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>exist</span> <span style=''>most</span> <span style=''>of</span> <span style=''>them</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>mounting</span> <span style=''>devices</span> <span style=''>However</span> <span style=''>in</span> <span style=''>real</span> <span style=''>world</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>find</span> <span style=''>these</span> <span style=''>animals</span> <span style=''>and</span> <span style=''>install</span> <span style=''>mounting</span> <span style=''>devices</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>animal</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>monitoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>utilizing</span> <span style=''>wireless</span> <span style=''>sensor</span> <span style=''>networks</span> <span style=''>(WSNs)</span> <span style=''>and</span> <span style=''>unmanned</span> <span style=''>aerial</span> <span style=''>vehicle</span> <span style=''>(UAV)</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>is</span> <span style=''>to</span> <span style=''>detect</span> <span style='background-color:rgba(0, 255, 0, 0.5357142857142858);'>locations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>endangered</span> <span style=''>species</span> <span style=''>in</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>wildlife</span> <span style=''>areas</span> <span style=''>and</span> <span style=''>monitor</span> <span style=''>movement</span> <span style=''>of</span> <span style=''>animals</span> <span style=''>without</span> <span style=''>any</span> <span style=''>attached</span> <span style=''>devices</span> <span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>sensors</span> <span style=''>deployed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>throughout</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>area</span> <span style=''>are</span> <span style='back ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>Density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Filtering</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>Density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Filtering</span> <span style=''>(C</span> <span style=''>DF)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>online</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>C</span> <span style=''>DF</span> <span style=''>adapts</span> <span style=''>MCMC</span> <span style=''>sampling</span> <span style=''>to</span> <span style=''>the</span> <span style=''>online</span> <span style=''>setting</span> <span style=''>sampling</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>(a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>estimates)</span> <span style=''>as</span> <span style=''>new</span> <span style=''>data</span> <span style=''>arrive</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantities</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eliminate</span> <span style=''>the</span> <span style=''>need</span> <span style=''>to</span> <span style=''>store</span> <span style=''>or</span> <span style=''>process</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>dataset</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>and</span> <span style=''>offer</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style=''>features</span> <span style=''>Often</span> <span style=''>these</span> <span style=''>include</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>in</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>and</span> <span style=''>runtime</span> <span style=''>and</span> <span style=''>improved</span> <span style=''>mixing</span> <span style=''>along</span> <span style=''>with</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>through</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stability</span> <span style=''>Analysis</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3650793650793651);'>Regularized</span> <span style=''>Least</span> <span style=''>Squares</span> <span style='background-color:rgba(255, 0, 0, 0.517391304347826);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>discuss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>for</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>noisy</span> <span style=''>labels</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>are</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.517391304347826);'>regression</span> <span style=''>and</span> <span style=''>they</span> <span style=''>involve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3461538461538461);'>minimization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3650793650793651);'>regularized</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functionals</span> <span style=''>such</span> <span style=''>as</span> <span style=''>L(f)</span> <span style=''>1N</span> <span style=''>sum</span> <span style=''>i</span> <span style=''>(f(x</span> <span style=''>i)</span> <span style=''>y</span> <span style=''>i)2</span> <span style=''>lambda</span> <span style=''>||f||</span> <span style=''>H2</span> <span style=''>We</span> <span style=''>shall</span> <span style=''>call</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>stable</span> <span style=''>if</span> <span style=''>when</span> <span style=''>y</span> <span style=''>i</span> <span style=''>is</span> <span style=''>a</span> <span style=''>noisy</span> <span style=''>version</span> <span style=''>of</span> <span style=''>f(x</span> <span style=''>i)</span> <span style=''>for</span> <span style=''>some</span> <span style=''>function</span> <span style=''>f</span> <span style=''>in</span> <span style=''>H</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.48648648648648646);'>converges</span> <span style=''>to</span> <span style=''>f</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>term</span> <span style=''>and</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>vanish</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>two</span> <span style=''>flavors</span> <span style=''>of</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>one</span> <span style=''>where</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>of</span> <span style=''>N</span> <span style=''>points</span> <span style=''>remains</span> <span style=''>fixed</span> <span style=''>and</span> <span style=''>the</span> <span style=''>other</span> <span style=''>where</span> <span style=''>N</span> <span style=''>infinity</span> <span style=''>For</span> <span style=''>the</span> <span style=''>case</span> <span style=''>where</span> <span style=''>N</span> <span style=''>infinity</span> <span style=''>we</span> <span style=''>give</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style=''>Accepts</span> <span style=''>and</span> <span style=''>Rejects</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identification</span> <span style=''>of</span> <span style=''>Top</span> <span style=''>Arms</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Bandits</span> <br/><br/><span style=''>We</span> <span style=''>address</span> <span style=''>the</span> <span style=''>M</span> <span style=''>best</span> <span style=''>arm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandits</span> <span style=''>A</span> <span style=''>player</span> <span style=''>has</span> <span style=''>a</span> <span style=''>limited</span> <span style=''>budget</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>K</span> <span style=''>arms</span> <span style=''>(MK)</span> <span style=''>and</span> <span style=''>once</span> <span style=''>pulled</span> <span style=''>each</span> <span style=''>arm</span> <span style=''>yields</span> <span style=''>a</span> <span style=''>reward</span> <span style=''>drawn</span> <span style=''>(independently)</span> <span style=''>from</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>top</span> <span style=''>M</span> <span style=''>arms</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>of</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>proceeds</span> <span style=''>in</span> <span style=''>rounds</span> <span style=''>to</span> <span style=''>deactivate</span> <span style=''>arms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteratively</span> <span style=''>At</span> <span style=''>each</span> <span style=''>round</span> <span style=''>the</span> <span style=''>budget</span> <span style=''>is</span> <span style=''>divided</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>function</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>remaining</span> <span style=''>arms</span> <span style=''>and</span> <span style=''>the</span> <span style=''>arms</span> <span style=''>are</span> <span style=''>pulled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspondingly</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>rule</span> <span style=''>the</span> <span style=''>deactivated</span> <span style=''>arm</span> <span style=''>at</span> <span style=''>each</span> <span style=''>round</span> <span style=''>may</span> <span style=''>be</span> <span style=''>accepted</span> <span style=''>or</span> <span style=''>rejected</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>outputs</span> <span style=''>the</span> <span style=''>accepted</span> <span style=''>arms</span> <span style=''>that</span> <span style=''>should</span> <span style=''>ideally</span> <span style=''>be</span> <span style=''>the</span> <span style=''>top</span> <span style=''>M</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.13189964157706094)
# 	segmentation (0.07096774193548387)
# 	experimental (0.14301075268817204)
# 	architecture (0.08781362007168458)
# 	information (0.24480286738351253)
# 	representation (0.13548387096774195)
# 	detection (0.11971326164874552)
# 	different (0.2770609318996416)
# 	convolutional (0.13405017921146953)
# 	recognition (0.14444444444444443)
#
# Some Statistics words are:
# 	stochastic (0.13333333333333333)
# 	variables (0.13681592039800994)
# 	estimation (0.16119402985074627)
# 	theoretical (0.1482587064676617)
# 	statistical (0.15223880597014924)
# 	distribution (0.1845771144278607)
# 	algorithm (0.3965174129353234)
# 	dimensional (0.17960199004975125)
# 	inference (0.19651741293532338)
# 	regression (0.1736318407960199)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="571b09be-0c98-430b-8778-1eca2e696df6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("571b09be-0c98-430b-8778-1eca2e696df6")) {                    Plotly.newPlot(                        "571b09be-0c98-430b-8778-1eca2e696df6",                        [{"x":["beneficial","reinforcement","variational","investigate","employing","knowledge","applications","synthetic","distributions","posterior","uncertainty","including","framework","efficient","probability","information","parameters","sequential","structural","superiority","contextual","experiments","individual","independent","preprocessing","manufacturing","importance","granularity","important","generates","predicting","different","induction","discusses","encountered","definition","experience","semiconductor","representation","rejection","engineers","facilitate","understanding","engineering","unsupervised","assistant","adaptation","autonomous","transductive","unlabeled","impractical","detectors","intervention","efficiently","available","validated","continuously","objective","constantly","precision","structure","streaming","algorithm","confident","themselves","paramount","generated","generating","capability","realistic","appearing","adversarial","recognition","generation","detection","deployment","commercial","illustrate","researchers","extensive","utilizing","mitigating","generative","demonstrate","presentation","discriminate","biometric","susceptibility","synthetically","convolutional","experimental","reliability","evaluated","interpolation","handwritten","alternative","principled","hypothesis","approximate","separated","criterions","transforming","autoencoders","riemannian","stationary","distribution","observation","simulated","represented","generalization","similarity","consequently","distances","inspection","previously","transformation","simultaneously","informative","architecture","preserving","illustrated","recommendation","distributed","associated","described","regularization","algorithmic","methodologies","algorithms","developments","decisions","processes","artificial","dependent","implications","increasingly","responsible","intelligent","deliberation","direction","stakeholders","designers","technological","integrate","considerable","unification","complexity","inference","particular","biomedical","description","polynomial","precisely","ontologies","decidable","attention","redundancies","significant","solutions","constrain","stochastic","separable","introduces","supervision","representations","collapsing","remarkably","questions","defeasible","structured","formalization","approaches","monotonic","reasoning","conclusion","construction","disjunctive","intricate","argumentation","subtleties","regarding","arguments","systematically","computation","artifacts","experimentation","influence","relatively","architectures","performance","compression","comprehensive","currently","verification","strengths","brightness","characteristics","squeezenet","occlusion","descriptor","degradations","improving","covariates","literature","specifically","potential","exploring","weaknesses","detrimental","techniques","googlenet","discussed","preliminary","constructing","expressed","computationally","mathematical","evaluating","successfully","disciplines","versatile","isomorphism","implication","evolutionary","assistants","interpretation","automatically","generator","developed","examining","scientific","establishing","accumulated","feasibility","corresponding","mathematics","considered","interacting","dimensional","benchmarks","orthogonal","experiment","regression","convergence","optimally","satisfies","aggregation","constraints","generalized","component","optimization","coefficients","arbitrar ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	criterions
# 	physionet
# 	conjugacy
# 	parameterizations
# 	homoscedastic
# 	textitnot
# 	heteroscedastic
# 	martingale
# 	macroeconomic
# 	supercomputers
# 	ultrametric
# 	automates
# 	fluctuate
# 	seasonality
# 	accounted
# 	parallels
# 	manifested
# 	overfitted
# 	distributedly
# 	physiologic
# Some words which never appear in Statistics papers:
# 	assistant
# 	constantly
# 	susceptibility
# 	deliberation
# 	designers
# 	decidable
# 	redundancies
# 	defeasible
# 	disjunctive
# 	argumentation
# 	implication
# 	assistants
# 	utterance
# 	utterances
# 	vagueness
# 	predicates
# 	imprecision
# 	connectives
# 	overwhelm
# 	monocular

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.078343851008158e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
